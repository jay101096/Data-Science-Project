# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\prabh\Downloads\1568699544_comcast_telecom_complaints_data\Comcast_telecom_complaints_data.csv")

# %%
df
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-15
# 1      223441       Payment disappear - service got disconnected  04-08-15
# 2      242732                                  Speed and Service  18-04-15
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4      307175         Comcast not working and no service to boot  26-05-15
# ...       ...                                                ...       ...
# 2219   213550                               Service Availability  04-02-15
# 2220   318775         Comcast Monthly Billing for Returned Modem  06-02-15
# 2221   331188                            complaint about comcast  06-09-15
# 2222   360489             Extremely unsatisfied Comcast customer  23-06-15
# 2223   363614               Comcast, Ypsilanti MI Internet Speed  24-06-15
#
# ...

# %%
df.isnull().sum()
# Out:
# Ticket #                       0
# Customer Complaint             0
# Date                           0
# Date_month_year                0
# Time                           0
# Received Via                   0
# City                           0
# State                          0
# Zip code                       0
# Status                         0
# Filing on Behalf of Someone    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   object
#  3   Date_month_year              2224 non-null   object
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 191.2+ KB

# %%
df["Date"]=pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   datetime64[ns]
#  3   Date_month_year              2224 non-null   object
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 191.2+ KB

# %%
df["Month"]=df["Date"].dt.month_name()

# %%
df
# Out:
#      Ticket #                                 Customer Complaint       Date  \
# 0      250635                      Comcast Cable Internet Speeds 2015-04-22
# 1      223441       Payment disappear - service got disconnected 2015-04-08
# 2      242732                                  Speed and Service 2015-04-18
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4      307175         Comcast not working and no service to boot 2015-05-26
# ...       ...                                                ...        ...
# 2219   213550                               Service Availability 2015-04-02
# 2220   318775         Comcast Monthly Billing for Returned Modem 2015-06-02
# 2221   331188                            complaint about comcast 2015-06-09
# 2222   360489             Extremely unsatisfied Comcast customer 2015-06-23
# 2223   363614               Comcast, Ypsilanti MI Internet Speed 2015-06-24
#
# ...

# %%
dates= df.groupby("Date").size()

# %%
dates
# Out:
# Date
# 2015-04-01    18
# 2015-04-02    27
# 2015-04-03    15
# 2015-04-04    12
# 2015-04-05     6
#               ..
# 2015-06-26    55
# 2015-06-27    39
# 2015-06-28    27
# 2015-06-29    51
# 2015-06-30    53
# Length: 91, dtype: int64

# %%
daily = pd.DataFrame(dates).reset_index()

# %%
daily.rename(columns={0:"count"}, inplace = True)

# %%
daily
# Out:
#          Date  count
# 0  2015-04-01     18
# 1  2015-04-02     27
# 2  2015-04-03     15
# 3  2015-04-04     12
# 4  2015-04-05      6
# ..        ...    ...
# 86 2015-06-26     55
# 87 2015-06-27     39
# 88 2015-06-28     27
# 89 2015-06-29     51
# 90 2015-06-30     53
#
# [91 rows x 2 columns]

# %%
daily.plot(x="Date", y="count", kind="line")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
daily.sort_values(["count"], ascending = False)
# Out:
#          Date  count
# 84 2015-06-24    218
# 83 2015-06-23    190
# 85 2015-06-25     98
# 86 2015-06-26     55
# 90 2015-06-30     53
# ..        ...    ...
# 46 2015-05-17      7
# 41 2015-05-12      7
# 4  2015-04-05      6
# 10 2015-04-11      5
# 32 2015-05-03      5
#
# [91 rows x 2 columns]

# %%
mnth = df.groupby("Month").size()

# %%
mnth
# Out:
# Month
# April     545
# June     1280
# May       399
# dtype: int64

# %%
mnth_df=pd.DataFrame(mnth).reset_index()

# %%
mnth_df.rename(columns={0:"Count"}, inplace = True)

# %%
mnth_df
# Out:
#    Month  Count
# 0  April    545
# 1   June   1280
# 2    May    399

# %%
mnth_df.plot(x="Month", y="Count", kind="bar")
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df["Customer Complaint"].value_counts()
# Out:
# Comcast                                          83
# Comcast Internet                                 18
# Comcast Data Cap                                 17
# comcast                                          13
# Comcast Billing                                  11
#                                                  ..
# Improper Billing and non resolution of issues     1
# Deceptive trade                                   1
# intermittent internet                             1
# Internet Speed on Wireless Connection             1
# Comcast, Ypsilanti MI Internet Speed              1
# Name: Customer Complaint, Length: 1841, dtype: int64

# %%
df["Customer Complaint"].str.upper().value_counts()
# Out:
# COMCAST                                                            102
# COMCAST DATA CAP                                                    30
# COMCAST INTERNET                                                    29
# COMCAST DATA CAPS                                                   21
# COMCAST BILLING                                                     18
#                                                                   ...
# MONTHLY DATA CAPS                                                    1
# COMCAST/XFINITY POOR SERVICE, FRAUDULENT BILLING AND COLLECTION      1
# LOST EMAILS/BILLING                                                  1
# IMPROPER BILLING AND NON RESOLUTION OF ISSUES                        1
# COMCAST, YPSILANTI MI INTERNET SPEED                                 1
# Name: Customer Complaint, Length: 1740, dtype: int64

# %%
df["Status"].unique()
# Out:
# array(['Closed', 'Open', 'Solved', 'Pending'], dtype=object)

# %%
df["New_Status"]=["Open"   if x == "Open" or x == "Pending"    else "Closed"    for x in df["Status"]]

# %%
df
# Out:
#      Ticket #                                 Customer Complaint       Date  \
# 0      250635                      Comcast Cable Internet Speeds 2015-04-22
# 1      223441       Payment disappear - service got disconnected 2015-04-08
# 2      242732                                  Speed and Service 2015-04-18
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4      307175         Comcast not working and no service to boot 2015-05-26
# ...       ...                                                ...        ...
# 2219   213550                               Service Availability 2015-04-02
# 2220   318775         Comcast Monthly Billing for Returned Modem 2015-06-02
# 2221   331188                            complaint about comcast 2015-06-09
# 2222   360489             Extremely unsatisfied Comcast customer 2015-06-23
# 2223   363614               Comcast, Ypsilanti MI Internet Speed 2015-06-24
#
# ...

# %%
df["New_Status"].unique()
# Out:
# array(['Closed', 'Open'], dtype=object)

# %%
State_Complaint=df.groupby(["State", "New_Status"]).size().unstack().fillna(0)

# %%
State_Complaint
# Out:
# New_Status            Closed  Open
# State
# Alabama                 17.0   9.0
# Arizona                 14.0   6.0
# Arkansas                 6.0   0.0
# California             159.0  61.0
# Colorado                58.0  22.0
# Connecticut              9.0   3.0
# Delaware                 8.0   4.0
# District Of Columbia    14.0   2.0
# District of Columbia     1.0   0.0
# Florida                201.0  39.0
# Georgia                208.0  80.0
# Illinois               135.0  29.0
# Indiana                 50.0   9.0
# Iowa                     1.0   0.0
# Kansas                   1.0   1.0
# Kentucky                 4.0   3.0
# Louisiana               12.0   1.0
# Maine                    3.0   2.0
# Maryland                63.0  15.0
# Massachusetts           50.0  11.0
# Michigan                92.0  23.0
# Minnesota               29.0   4.0
# Mississippi             23.0  16.0
# Missouri                 3.0   1.0
# Montana                  1.0   0.0
# ...

# %%
State_Complaint.plot.bar(stacked=True, figsize=(8,5))
# Out:
# <AxesSubplot:xlabel='State'>

# %%
df.groupby("State").size().sort_values(ascending=False)[:5]
# Out:
# State
# Georgia       288
# Florida       240
# California    220
# Illinois      164
# Tennessee     143
# dtype: int64

# %%
df.to_csv("Comcast_data.csv")

# %%
unresolved_data=df.groupby(["State", "New_Status"]).size().unstack().fillna(0).sort_values(by="Open", ascending=False)

# %%
unresolved_data
# Out:
# New_Status            Closed  Open
# State
# Georgia                208.0  80.0
# California             159.0  61.0
# Tennessee               96.0  47.0
# Florida                201.0  39.0
# Illinois               135.0  29.0
# Washington              75.0  23.0
# Michigan                92.0  23.0
# Colorado                58.0  22.0
# Texas                   49.0  22.0
# Pennsylvania           110.0  20.0
# New Jersey              56.0  19.0
# Mississippi             23.0  16.0
# Maryland                63.0  15.0
# Oregon                  36.0  13.0
# Virginia                49.0  11.0
# Massachusetts           50.0  11.0
# Alabama                 17.0   9.0
# Indiana                 50.0   9.0
# Utah                    16.0   6.0
# Arizona                 14.0   6.0
# New Hampshire            8.0   4.0
# New Mexico              11.0   4.0
# Minnesota               29.0   4.0
# Delaware                 8.0   4.0
# West Virginia            8.0   3.0
# ...

# %%
unresolved_data["Unresolved_Comp_percentage"]=unresolved_data["Open"]/unresolved_data["Open"].sum()*100

# %%
unresolved_data
# Out:
# New_Status            Closed  Open  Unresolved_Comp_percentage
# State
# Georgia                208.0  80.0                   15.473888
# California             159.0  61.0                   11.798839
# Tennessee               96.0  47.0                    9.090909
# Florida                201.0  39.0                    7.543520
# Illinois               135.0  29.0                    5.609284
# Washington              75.0  23.0                    4.448743
# Michigan                92.0  23.0                    4.448743
# Colorado                58.0  22.0                    4.255319
# Texas                   49.0  22.0                    4.255319
# Pennsylvania           110.0  20.0                    3.868472
# New Jersey              56.0  19.0                    3.675048
# Mississippi             23.0  16.0                    3.094778
# Maryland                63.0  15.0                    2.901354
# Oregon                  36.0  13.0                    2.514507
# ...

# %%
df
# Out:
#      Ticket #                                 Customer Complaint       Date  \
# 0      250635                      Comcast Cable Internet Speeds 2015-04-22
# 1      223441       Payment disappear - service got disconnected 2015-04-08
# 2      242732                                  Speed and Service 2015-04-18
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4      307175         Comcast not working and no service to boot 2015-05-26
# ...       ...                                                ...        ...
# 2219   213550                               Service Availability 2015-04-02
# 2220   318775         Comcast Monthly Billing for Returned Modem 2015-06-02
# 2221   331188                            complaint about comcast 2015-06-09
# 2222   360489             Extremely unsatisfied Comcast customer 2015-06-23
# 2223   363614               Comcast, Ypsilanti MI Internet Speed 2015-06-24
#
# ...

# %%
resolved_data=df.groupby(["Received Via", "New_Status"]).size().unstack()

# %%
resolved_data
# Out:
# New_Status          Closed  Open
# Received Via
# Customer Care Call     864   255
# Internet               843   262

# %%
resolved_data["resolve_percentage"]=resolved_data["Closed"]/resolved_data["Closed"].sum()*100

# %%
resolved_data
# Out:
# New_Status          Closed  Open  resolve_percentage
# Received Via
# Customer Care Call     864   255           50.615114
# Internet               843   262           49.384886
